# %%
# notebook_param = dbutils.widgets.get("notebook_param")
# print(f"Received notebook_param: {notebook_param}")

# %%
from_t1_param = dbutils.widget.get("param_from_job_1")

# %%
print(from_t1_param)

# %%
# partition_data_spark_conf = spark.conf.get("partitionDate")

# print(partition_data_spark_conf)

# %%
# import os
# partition_date_env_var = os.getenv("partitionDate")
# print(partition_date_env_var)

# %% [markdown]
# # CICD

# %%
print("Hello from notebook 2!")
